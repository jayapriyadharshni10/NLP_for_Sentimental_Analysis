# %%
from google.colab import files
uploaded = files.upload()

import pandas as pd
import io

# Auto-detect uploaded file name
filename = list(uploaded.keys())[0]

# Read CSV
df = pd.read_csv(io.BytesIO(uploaded[filename]))
df.head()
# Out:
#      <input type="file" id="files-5adf641e-05c9-4e74-956d-2568932eef36" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5adf641e-05c9-4e74-956d-2568932eef36">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install textblob
from textblob import TextBlob
import matplotlib.pyplot as plt

# %%
def get_sentiment(text):
    blob = TextBlob(str(text))
    polarity = blob.sentiment.polarity
    if polarity > 0:
        return "Positive"
    elif polarity < 0:
        return "Negative"
    else:
        return "Neutral"

# %%
df['Sentiment'] = df['Review'].apply(get_sentiment)
df.head()
# Out:
#                              Review Sentiment
# 0           This product is amazing  Positive
# 1             Worst experience ever  Negative
# 2  I love the quality and packaging  Positive
# 3                 Not good, not bad  Negative
# 4       The delivery was super fast  Positive

# %%
df['Sentiment'].value_counts().plot(kind='bar', color=['green', 'red', 'gray'])
plt.title("Sentiment Analysis Result")
plt.xlabel("Sentiment")
plt.ylabel("Number of Reviews")
plt.grid()
plt.show()
df.to_csv("sentiment_output.csv", index=False)
files.download("sentiment_output.csv")

# %% [markdown]
# # Sentiment Analysis using NLP (TextBlob)
#
# ## Objective:
# To classify user reviews as Positive, Negative or Neutral using TextBlob in Python.
#
# ## Tools Used:
# - Python
# - Pandas
# - TextBlob
# - Matplotlib
# - Google Colab
#
# ## Steps:
# 1. Uploaded reviews.csv file
# 2. Used TextBlob to compute polarity
# 3. Applied classification logic
# 4. Plotted a bar graph
# 5. Exported results
#
# ## Output:
# - Table with Sentiment column
# - Sentiment bar graph
# - Output CSV file
#
# ## Conclusion:
# This mini-project shows basic NLP using TextBlob and can be expanded to real-time applications like tweets or customer feedback.
